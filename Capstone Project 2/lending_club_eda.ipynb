# %%
import pandas as pd
from sqlalchemy import create_engine
from pandas_profiling import ProfileReport
import os
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import datetime as datetime
import pickle

# %%
with open('lending_club_wrangling_pick.pkl', 'rb') as pickle_file:
    df = pickle.load(pickle_file)

# %%
df.shape
# Out:
# (2260668, 108)

# %% [markdown]
# Can we identify any numerical values as categorical data?

# %%
df.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('O'), dtype('<M8[ns]')], dtype=object)

# %%
df.select_dtypes('number') == 1.0 | df.select_dtypes('number') == 0.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     265         #  (xint or xbool) and (yint or bool)
# --> 266         result = op(x, y)
#     267     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     279             try:
# ...

# %%
df_num_categorial.sum().sort_values(ascending = False)
# Out:
# policy_code           2260668
# inq_last_6mths         584390
# num_tl_op_past_12m     558928
# open_il_24m            439811
# open_acc_6m            434092
#                        ...
# total_bc_limit              0
# total_rev_hi_lim            0
# pct_tl_nvr_dlq              0
# tot_hi_cred_lim             0
# loan_amnt                   0
# Length: 88, dtype: int64

# %%
df_num_index = df_num_categorial.columns[(df_num_categorial == 0.0).all()]

# %%
df[df_num_index]
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  \
# 0           3600.0       3600.0           3600.0     13.99       123.03
# 1          24700.0      24700.0          24700.0     11.99       820.28
# 2          20000.0      20000.0          20000.0     10.78       432.66
# 3          35000.0      35000.0          35000.0     14.85       829.90
# 4          10400.0      10400.0          10400.0     22.45       289.91
# ...            ...          ...              ...       ...          ...
# 2260694    24000.0      24000.0          24000.0     12.79       543.50
# 2260695    24000.0      24000.0          24000.0     10.49       515.74
# 2260696    40000.0      40000.0          40000.0     10.49       859.56
# 2260697    24000.0      24000.0          24000.0     14.49       564.56
# 2260698    14000.0      14000.0          14000.0     14.49       329.33
#
#          fico_range_low  fico_range_high   total_pymnt  total_pymnt_inv  \
# ...
